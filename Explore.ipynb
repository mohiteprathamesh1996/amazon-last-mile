# %% [markdown]
# ### Importing Packages

# %%
import os
import requests
import numpy as np
import pandas as pd
import boto3
from botocore import UNSIGNED
from botocore.client import Config

# %%
s3 = boto3.client(
    's3',
    config=Config(signature_version=UNSIGNED)
)

bucket_name = "amazon-last-mile-challenges"

# %%
response = s3.list_objects_v2(Bucket=bucket_name)

for obj in response.get('Contents', []):
    print(obj['Key'])
# Out:
# almrrc2021/
# almrrc2021/License.txt
# almrrc2021/Readme.txt
# almrrc2021/almrrc2021-data-evaluation/
# almrrc2021/almrrc2021-data-evaluation/model_apply_inputs/
# almrrc2021/almrrc2021-data-evaluation/model_apply_inputs/eval_package_data.json
# almrrc2021/almrrc2021-data-evaluation/model_apply_inputs/eval_route_data.json
# almrrc2021/almrrc2021-data-evaluation/model_apply_inputs/eval_travel_times.json
# almrrc2021/almrrc2021-data-evaluation/model_apply_outputs/
# almrrc2021/almrrc2021-data-evaluation/model_build_inputs/
# almrrc2021/almrrc2021-data-evaluation/model_build_outputs/
# almrrc2021/almrrc2021-data-evaluation/model_score_inputs/
# almrrc2021/almrrc2021-data-evaluation/model_score_inputs/eval_actual_sequences.json
# almrrc2021/almrrc2021-data-evaluation/model_score_inputs/eval_invalid_sequence_scores.json
# almrrc2021/almrrc2021-data-evaluation/model_score_outputs/
# almrrc2021/almrrc2021-data-training/
# almrrc2021/almrrc2021-data-training/model_apply_inputs/
# almrrc2021/almrrc2021-data-training/model_apply_inputs/new_package_data.json
# almrrc2021/almrrc2021-data-training/model_apply_inputs/new_route_data.json
# almrrc2021/almrrc2021-data-training/model_apply_inputs/new_travel_times.json
# almrrc2021/almrrc2021-data-training/model_apply_inputs/readme.md
# almrrc2021/almrrc2021-data-training/model_apply_outputs/
# almrrc2021/almrrc2021-data-training/model_apply_outputs/proposed_sequences.json
# almrrc2021/almrrc2021-data-training/model_apply_outputs/readme.md
# almrrc2021/almrrc2021-data-training/model_build_inputs/actual_sequences.json
# almrrc2021/almrrc2021-data-training/model_build_inputs/invalid_sequence_scores.json
# almrrc2021/almrrc2021-data-training/model_build_inputs/package_data.json
# almrrc2021/almrrc2021-data-training/model_build_inputs/readme.md
# almrrc2021/almrrc2021-data-training/model_build_inputs/route_data.json
# almrrc2021/almrrc2021-data-training/model_build_inputs/travel_times.json
# almrrc2021/almrrc2021-data-training/model_build_outputs/
# almrrc2021/almrrc2021-data-training/model_build_outputs/readme.md
# almrrc2021/almrrc2021-data-training/model_score_inputs/new_actual_sequences.json
# almrrc2021/almrrc2021-data-training/model_score_inputs/new_invalid_sequence_scores.json
# almrrc2021/almrrc2021-data-training/model_score_inputs/readme.md
# almrrc2021/almrrc2021-data-training/model_score_outputs/
# almrrc2021/almrrc2021-data-training/model_score_outputs/readme.md
# almrrc2021/almrrc2021-data-training/model_score_outputs/scores.json
# almrrc2021/almrrc2021-data-training/model_score_timings/
# almrrc2021/almrrc2021-data-training/model_score_timings/model_apply_time.json
# almrrc2021/almrrc2021-data-training/model_score_timings/model_build_time.json
# almrrc2021/almrrc2021-data-training/model_score_timings/readme.md
